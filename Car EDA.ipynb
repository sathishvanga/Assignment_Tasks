# %% [markdown]
# ### Importing Libraries

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %% [markdown]
# ### Loading the Dataset

# %%
df = pd.read_csv(r"C:\Users\sathi\Downloads\car_df_EDA.csv")

# %%
df.head()
# Out:
#    Unnamed: 0.1  Unnamed: 0         make fuel_type aspiration num_of_doors  \
# 0             0           1  alfa-romero       gas        std          two
# 1             1           2  alfa-romero       gas        std          two
# 2             2           3  alfa-romero       gas        std          two
# 3             3           4         audi       gas        std         four
# 4             4           5         audi       gas        std         four
#
#     body_style drive_wheels engine_location  wheel_base  ...  engine_type  \
# 0  convertible          rwd           front        88.6  ...         dohc
# 1  convertible          rwd           front        88.6  ...         dohc
# 2    hatchback          rwd           front        94.5  ...         ohcv
# 3        sedan          fwd           front        99.8  ...          ohc
# 4        sedan          4wd           front        99.4  ...          ohc
#
# ...

# %% [markdown]
# ### Data Cleaning

# %%
df.drop(["Unnamed: 0.1","Unnamed: 0"],axis=1,inplace=True)

# %% [markdown]
# ### Structural Errors

# %%
pd.set_option("display.max_rows",100)
pd.set_option("display.max_columns",50)
for i in df.columns:
    #print(df[i])
    print(f"{i}",df[i].unique())
    print()
# Out:
# make ['alfa-romero' 'audi' 'bmw' 'chevrolet' 'dodge' 'honda' 'isuzu' 'jaguar'
#  'mazda' 'mercedes-benz' 'mercury' 'mitsubishi' 'nissan' 'peugot'
#  'plymouth' 'porsche' 'renault' 'saab' 'subaru' 'toyota' 'volkswagen'
#  'volvo']
#
# fuel_type ['gas' 'diesel']
#
# aspiration ['std' 'turbo']
#
# num_of_doors ['two' 'four' '?']
#
# body_style ['convertible' 'hatchback' 'sedan' 'wagon' 'hardtop']
#
# drive_wheels ['rwd' 'fwd' '4wd']
#
# engine_location ['front' 'rear']
#
# wheel_base [ 88.6  94.5  99.8  99.4 105.8  99.5 101.2   nan 103.5 110.   88.4  93.7
#  103.3  95.9  86.6  96.5  94.3  96.  113.  102.   93.1  95.3  98.8 104.9
#  106.7 115.6  96.6 120.9 112.  102.7  93.   96.3  95.1  97.2 100.4  91.3
#   99.2 107.9 114.2 108.   89.5  98.4  96.1  99.1  93.3  97.   96.9  95.7
#  102.4 102.9 104.5  97.3 104.3 109.1]
#
# length [168.8 171.2 176.6 177.3 192.7 178.2 176.8 189.  193.8 197.  141.1 155.9
#  158.8 157.3 174.6 173.2 144.6 150.  163.4 157.1 167.5 175.4 169.1 170.7
# ...

# %%
df["num_of_doors"].replace("?",np.nan,inplace=True)

df["num_of_doors"].replace("?",np.nan,inplace=True)

df["num_of_doors"].replace(["two","four"],[2,4],inplace=True)

df["num_of_cylinders"].replace(['four','six','five','three','twelve','two','eight'],[4,6,5,3,12,2,8],inplace=True)

df["horsepower"].replace("?",np.nan,inplace=True)

df["peak_rpm"].replace("?",np.nan,inplace=True)

df["price"].replace("?",np.nan,inplace=True)


df.head()
# Out:
#           make fuel_type aspiration  num_of_doors   body_style drive_wheels  \
# 0  alfa-romero       gas        std           2.0  convertible          rwd
# 1  alfa-romero       gas        std           2.0  convertible          rwd
# 2  alfa-romero       gas        std           2.0    hatchback          rwd
# 3         audi       gas        std           4.0        sedan          fwd
# 4         audi       gas        std           4.0        sedan          4wd
#
#   engine_location  wheel_base  length  width  height  curb_weight engine_type  \
# 0           front        88.6   168.8   64.1    48.8         2548        dohc
# 1           front        88.6   168.8   64.1    48.8         2548        dohc
# 2           front        94.5   171.2   65.5    52.4         2823        ohcv
# 3           front        99.8   176.6   66.2    54.3         2337         ohc
# 4           front        99.4   176.6   66.4    54.3         2824         ohc
#
# ...

# %% [markdown]
# ### Missing Value Detection

# %%
df.isna().sum()
# Out:
# make                 0
# fuel_type            0
# aspiration           0
# num_of_doors         2
# body_style           0
# drive_wheels         0
# engine_location      0
# wheel_base           2
# length               0
# width                0
# height               0
# curb_weight          0
# engine_type          1
# num_of_cylinders     0
# engine_size          2
# fuel_system          0
# compression_ratio    0
# horsepower           2
# peak_rpm             2
# city_mpg             0
# highway_mpg          0
# price                8
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 208 entries, 0 to 207
# Data columns (total 22 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   make               208 non-null    object
#  1   fuel_type          208 non-null    object
#  2   aspiration         208 non-null    object
#  3   num_of_doors       206 non-null    float64
#  4   body_style         208 non-null    object
#  5   drive_wheels       208 non-null    object
#  6   engine_location    208 non-null    object
#  7   wheel_base         206 non-null    float64
#  8   length             208 non-null    float64
#  9   width              208 non-null    float64
#  10  height             208 non-null    float64
#  11  curb_weight        208 non-null    int64
#  12  engine_type        207 non-null    object
#  13  num_of_cylinders   208 non-null    int64
#  14  engine_size        206 non-null    float64
#  15  fuel_system        208 non-null    object
# ...

# %%
num = df.select_dtypes(exclude="object")
obj = df.select_dtypes(include="object")

# %%
#filling missing values for numerical features
for i in num.columns:
    #print(num[i])
    df[i].fillna(df[i].median(),inplace=True)

# %%
df.isna().sum()
# Out:
# make                 0
# fuel_type            0
# aspiration           0
# num_of_doors         0
# body_style           0
# drive_wheels         0
# engine_location      0
# wheel_base           0
# length               0
# width                0
# height               0
# curb_weight          0
# engine_type          1
# num_of_cylinders     0
# engine_size          0
# fuel_system          0
# compression_ratio    0
# horsepower           2
# peak_rpm             2
# city_mpg             0
# highway_mpg          0
# price                8
# dtype: int64

# %%
#filling missing values for categorical features
for i in obj.columns:
    df[i].fillna(df[i].mode()[0],inplace=True)

# %%
df.isna().sum()
# Out:
# make                 0
# fuel_type            0
# aspiration           0
# num_of_doors         0
# body_style           0
# drive_wheels         0
# engine_location      0
# wheel_base           0
# length               0
# width                0
# height               0
# curb_weight          0
# engine_type          0
# num_of_cylinders     0
# engine_size          0
# fuel_system          0
# compression_ratio    0
# horsepower           0
# peak_rpm             0
# city_mpg             0
# highway_mpg          0
# price                0
# dtype: int64

# %% [markdown]
# ### TypeCasting

# %%
df.dtypes
# Out:
# make                  object
# fuel_type             object
# aspiration            object
# num_of_doors         float64
# body_style            object
# drive_wheels          object
# engine_location       object
# wheel_base           float64
# length               float64
# width                float64
# height               float64
# curb_weight            int64
# engine_type           object
# num_of_cylinders       int64
# engine_size          float64
# fuel_system           object
# compression_ratio    float64
# horsepower            object
# peak_rpm              object
# city_mpg               int64
# highway_mpg            int64
# price                 object
# dtype: object

# %%
df["price"] = df["price"].astype("float64")

df["peak_rpm"] = df["peak_rpm"].astype("float64")

df["horsepower"] = df["horsepower"].astype("float64")

df.dtypes
df.drop_duplicates(inplace=True)

# %% [markdown]
# ## Univariate Analysis

# %% [markdown]
# ### Univariate Analysis On Numerical Features

# %%
numerical_columns = df.select_dtypes(exclude="object")
categorical_columns = df.select_dtypes(include="object")

# %%
#plt.style.use('classic')

plt.style.use("tableau-colorblind10")

# %%
plt.style.available
# Out:
# ['Solarize_Light2',
#  '_classic_test_patch',
#  '_mpl-gallery',
#  '_mpl-gallery-nogrid',
#  'bmh',
#  'classic',
#  'dark_background',
#  'fast',
#  'fivethirtyeight',
#  'ggplot',
#  'grayscale',
#  'seaborn-v0_8',
#  'seaborn-v0_8-bright',
#  'seaborn-v0_8-colorblind',
#  'seaborn-v0_8-dark',
#  'seaborn-v0_8-dark-palette',
#  'seaborn-v0_8-darkgrid',
#  'seaborn-v0_8-deep',
#  'seaborn-v0_8-muted',
#  'seaborn-v0_8-notebook',
#  'seaborn-v0_8-paper',
#  'seaborn-v0_8-pastel',
#  'seaborn-v0_8-poster',
#  'seaborn-v0_8-talk',
#  'seaborn-v0_8-ticks',
#  'seaborn-v0_8-white',
#  'seaborn-v0_8-whitegrid',
#  'tableau-colorblind10']

# %%
df["num_of_doors"].plot(kind="hist",xlabel="No of Car Doors")
# Out:
# <Axes: xlabel='No of Car Doors', ylabel='Frequency'>

# %% [markdown]
# * A histogram is used to visualize the distribution of numerical data.
#
# **Insights from above Histogram**
# 1. 90 cars having 2 doors
# 2. 118 cars having 4 doors

# %%
df["num_of_doors"].plot(kind="box",xlabel="No of Car Doors")
# Out:
# <Axes: xlabel='No of Car Doors'>

# %%
df["num_of_doors"].plot(kind="kde",xlabel="No of Car Doors")
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# **Insights from above Density plot**
# 1. It is not following the normal distribution
# 2. The Data is not dristibuted normally

# %%
df["wheel_base"].plot(kind="hist",xlabel="Wheel Base",grid=True)
# Out:
# <Axes: xlabel='Wheel Base', ylabel='Frequency'>

# %% [markdown]
# **Insights from above Histogram**
# 1. Min Wheel Base is 86
# 2. Max Wheel Base is 121

# %%
df["wheel_base"].plot(kind="box",xlabel="Wheel Base",grid=True,vert=False)
# Out:
# <Axes: xlabel='Wheel Base'>

# %% [markdown]
# **Insights from above Boxplot**
# 1. Min Wheel Base is 86
# 2. Max Wheel Base is 121
# 3. Q1 is 94
# 4. Q2(Median) is 98
# 5. Q3 is 103
# 6. It is partially distributed

# %%
df["wheel_base"].plot(kind="kde",xlabel="Wheel Base",grid=True)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# **Insights from above Density plot**
# 1. It is following the normal distribution
# 2. The Data is Partially dristibuted

# %%
df["length"].plot(kind="hist",xlabel="Length",grid=True)
# Out:
# <Axes: xlabel='Length', ylabel='Frequency'>

# %% [markdown]
# **Insights from above Histogram**
# 1. Min length of cars is 141
# 2. Max length of cars is 208

# %%
df["length"].plot(kind="box",xlabel="Length",grid=True)
# Out:
# <Axes: xlabel='Length'>

# %% [markdown]
# **Insights from above Boxplot**
# 1. Min length of cars is 141
# 2. Max length of cars is 208
# 3. Q1 is 167
# 4. Q2(Median) is 174
# 5. Q3 is 183
# 6. It is partially distributed

# %%
df["length"].plot(kind="kde",xlabel="Length",grid=True)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# **Insights from above Density plot**
# 1. It is following the normal distribution
# 2. The Data is normally dristibuted

# %%
df["width"].plot(kind = "hist",xlabel="Width",grid=True)
# Out:
# <Axes: xlabel='Width', ylabel='Frequency'>

# %% [markdown]
# **Insights from above Histogram**
# 1. Min Width of cars is 60
# 2. Max Width of cars is 72

# %%
df["width"].plot(kind = "box",xlabel="Width",grid=True)
# Out:
# <Axes: xlabel='Width'>

# %% [markdown]
# **Insights from above Boxplot**
# 1. Min width of cars is 60
# 2. Max width of cars is 72
# 3. Q1 is 64
# 4. Q2(Median) is 65
# 5. Q3 is 67
# 6. It is partially distributed

# %%
df["width"].plot(kind = "kde",xlabel="Width",grid=True)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# **Insights from above Density plot**
# 1. It is following the normal distribution
# 2. The Data is normally dristibuted

# %%
df["height"].plot(kind = "hist",xlabel="Height",grid=True)
# Out:
# <Axes: xlabel='Height', ylabel='Frequency'>

# %% [markdown]
# **Insights from above Histogram**
# 1. Min Height of cars is 47
# 2. Max Height of cars is 60

# %%
df["height"].plot(kind = "box",xlabel="Height",grid=True)
# Out:
# <Axes: xlabel='Height'>

# %% [markdown]
# **Insights from above Boxplot**
# 1. Min Height of cars is 47
# 2. Max Height of cars is 60
# 3. Q1 is 52
# 4. Q2(Median) is 54
# 5. Q3 is 55
# 6. It is partially distributed

# %%
df["height"].plot(kind = "density",xlabel="Height",grid=True)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# **Insights from above Density plot**
# 1. It is following the normal distribution
# 2. The Data is partially dristibuted

# %%
df["curb_weight"].plot(kind="hist",xlabel = "Curb Weight",grid = True)
# Out:
# <Axes: xlabel='Curb Weight', ylabel='Frequency'>

# %% [markdown]
# **Insights from above Histogram**
# 1. Min Curb Weight of cars is 1500
# 2. Max Curb Weight of cars is 400

# %%
df["curb_weight"].plot(kind="box",xlabel = "Curb Weight",grid = True)
# Out:
# <Axes: xlabel='Curb Weight'>

# %% [markdown]
# **Insights from above Boxplot**
# 1. Min Curb Weight of cars is 1500
# 2. Max lCurb Weight of cars is 4000
# 3. Q1 is 2200
# 4. Q2(Median) is 2450
# 5. Q3 is 2900
# 6. It is partially distributed

# %%
df["curb_weight"].plot(kind="kde",xlabel = "Curb Weight",grid = True)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# **Insights from above Density plot**
# 1. It is following the normal distribution
# 2. The Data is normally dristibuted

# %%
df["num_of_cylinders"].plot(kind="hist",xlabel = "No of Cylinders",grid = True)
# Out:
# <Axes: xlabel='No of Cylinders', ylabel='Frequency'>

# %% [markdown]
# **Insights from above Histogram**
# 1. Min No of Cylinders of cars is 2
# 2. Max No of Cylinders of cars is 8

# %%
df["num_of_cylinders"].max()
# Out:
# 12

# %%
df["num_of_cylinders"].plot(kind="box",xlabel = "No of Cylinders",grid = True)
# Out:
# <Axes: xlabel='No of Cylinders'>

# %%
df["num_of_cylinders"].plot(kind="kde",xlabel = "No of Cylinders",grid = True)
# Out:
# <Axes: ylabel='Density'>

# %%
df["engine_size"].plot(kind="hist",grid = True)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# **Insights from above Histogram**
# 1. Min Width of cars is 50
# 2. Max Width of cars is 300

# %%
df["engine_size"].plot(kind="box",grid = True)
# Out:
# <Axes: >

# %% [markdown]
# **Insights from above Boxplot**
# 1. Min Engine Size of cars is 54
# 2. Max Engine Size of cars is 202
# 3. Q1 is 100
# 4. Q2(Median) is 125
# 5. Q3 is 148
# 6. It is partially distributed

# %%
df["engine_size"].plot(kind="kde",grid = True)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# **Insights from above Density plot**
# 1. It is following the normal distribution
# 2. The Data is normally dristibuted

# %%
df["compression_ratio"].plot(kind="hist",grid = True)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# **Insights from above Histogram**
# 1. Min Compression Ratio of cars is 8
# 2. Max Compression Ratio of cars is 22

# %%
df["compression_ratio"].plot(kind="box",grid = True)
# Out:
# <Axes: >

# %% [markdown]
# **Insights from above Boxplot**
# 1. Min Compression Ratio of cars is 7
# 2. Max Compression Ratio of cars is 11
# 3. Q1 is 9
# 4. Q2(Median) is 9
# 5. Q3 is 9
# 6. It is not  partially distributed

# %%
df["compression_ratio"].plot(kind="kde",grid = True)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# **Insights from above Density plot**
# 1. It is not following the normal distribution
# 2. The Data is not normally dristibuted

# %%
df["horsepower"].plot(kind="hist",grid = True)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# **Insights from above Histogram**
# 1. Min Horsepower of cars is 50
# 2. Max Horsepower of cars is 300

# %%
df["horsepower"].plot(kind="box",grid = True)
# Out:
# <Axes: >

# %% [markdown]
# **Insights from above Boxplot**
# 1. Min Horsepower of cars is 50
# 2. Max Horsepower of cars is 190
# 3. Q1 is 70
# 4. Q2(Median) is 95
# 5. Q3 is 120
# 6. It is  partially distributed

# %%
df["horsepower"].plot(kind="kde",grid = True)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# **Insights from above Density plot**
# 1. It is  following the normal distribution
# 2. The Data is partially dristibuted

# %%
df["peak_rpm"].plot(kind="hist",grid = True)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# **Insights from above Histogram**
# 1. Min Peak RPM of cars is 4000
# 2. Max Peak RPM of cars is 6500

# %%
df["peak_rpm"].plot(kind="box",grid = True)
# Out:
# <Axes: >

# %% [markdown]
# **Insights from above Boxplot**
# 1. Min  Peak RPM  of cars is 4000
# 2. Max  Peak RPM  of cars is 6500
# 3. Q1 is 4800
# 4. Q2(Median) is 5200
# 5. Q3 is 5500
# 6. It is partially distributed

# %%
df["peak_rpm"].plot(kind="kde",grid = True)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# **Insights from above Density plot**
# 1. It is following the normal distribution
# 2. The Data is normally dristibuted

# %%
df["city_mpg"].plot(kind="hist",grid = True)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# **Insights from above Histogram**
# 1. Min City Milege of cars is 50
# 2. Max City Milege of cars is 13

# %%
df["city_mpg"].plot(kind="box",grid = True)
# Out:
# <Axes: >

# %% [markdown]
# **Insights from above Boxplot**
# 1. Min City Milege of cars is 13
# 2. Max City Milege of cars is 45
# 3. Q1 is 19
# 4. Q2(Median) is 24
# 5. Q3 is 30
# 6. It is partially distributed

# %%
df["city_mpg"].plot(kind="kde",grid = True)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# **Insights from above Density plot**
# 1. It is following the normal distribution
# 2. The Data is normally dristibuted

# %%
df["highway_mpg"].plot(kind="hist",grid = True)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# **Insights from above Histogram**
# 1. Min Highway Milege of cars is 17
# 2. Max Highway Milege of cars is 53

# %%
df["highway_mpg"].plot(kind="box",grid = True)
# Out:
# <Axes: >

# %% [markdown]
# **Insights from above Boxplot**
# 1. Min Highway Milege of cars is 17
# 2. Max Highway Milege of cars is 47
# 3. Q1 is 25
# 4. Q2(Median) is 30
# 5. Q3 is 33
# 6. It is partially distributed

# %%
df["highway_mpg"].plot(kind="kde",grid = True)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# **Insights from above Density plot**
# 1. It is following the normal distribution
# 2. The Data is normally dristibuted

# %%
numerical_columns.columns
# Out:
# Index(['num_of_doors', 'wheel_base', 'length', 'width', 'height',
#        'curb_weight', 'num_of_cylinders', 'engine_size', 'compression_ratio',
#        'horsepower', 'peak_rpm', 'city_mpg', 'highway_mpg', 'price'],
#       dtype='object')

# %%
df["price"].plot(kind="hist",grid = True)
# Out:
# <Axes: ylabel='Frequency'>

# %% [markdown]
# **Insights from above Histogram**
# 1. Min Price of cars is 5000
# 2. Max Price of cars is 45000

# %%
df["price"].plot(kind="box",grid = True)
# Out:
# <Axes: >

# %% [markdown]
# **Insights from above Boxplot**
# 1. Min Price of cars is 5000
# 2. Max Price of cars is 27000
# 3. Q1 is 7500
# 4. Q2(Median) is 11000
# 5. Q3 is 16000
# 6. It is not distributed

# %%
df["price"].plot(kind="kde",grid = True)
# Out:
# <Axes: ylabel='Density'>

# %% [markdown]
# **Insights from above Density plot**
# 1. It is not following the normal distribution
# 2. The Data is not normally dristibuted

# %% [markdown]
# ### Univariate Analysis On Categorical Features

# %%
df["make"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='make'>

# %% [markdown]
# **Insights from above Bar plot**
# 1. Max no of Cars Toyota
# 2. Min no of Cars Mercury

# %%
sns.countplot(data=df,x="make")
# Out:
# <Axes: xlabel='make', ylabel='count'>

# %%
df["fuel_type"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='fuel_type'>

# %% [markdown]
# **Insights from above Bar plot**
# 1. Max Fuel Type is Gas
# 2. Min Fuel Type is Diesel

# %%
sns.countplot(data=df,x="fuel_type")
# Out:
# <Axes: xlabel='fuel_type', ylabel='count'>

# %%
df["fuel_type"].value_counts().plot(kind="pie",autopct = "%1.1f",legend = True,ylabel="Percentage")
# Out:
# <Axes: ylabel='Percentage'>

# %% [markdown]
# **Insights from above Pie Chart**
# 1. 89.9% of gas cars
# 2. 10.1% of diesel cars

# %%
categorical_columns.columns
# Out:
# Index(['make', 'fuel_type', 'aspiration', 'body_style', 'drive_wheels',
#        'engine_location', 'engine_type', 'fuel_system'],
#       dtype='object')

# %%
df["aspiration"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='aspiration'>

# %%
sns.countplot(data=df,x="aspiration")
# Out:
# <Axes: xlabel='aspiration', ylabel='count'>

# %%
df["aspiration"].value_counts().plot(kind="pie",autopct = "%1.1f",legend = True,ylabel="Percentage")
# Out:
# <Axes: ylabel='Percentage'>

# %%
categorical_columns.columns
# Out:
# Index(['make', 'fuel_type', 'aspiration', 'body_style', 'drive_wheels',
#        'engine_location', 'engine_type', 'fuel_system'],
#       dtype='object')

# %%
df["body_style"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='body_style'>

# %%
sns.countplot(data=df,x="body_style")
# Out:
# <Axes: xlabel='body_style', ylabel='count'>

# %%
df["body_style"].value_counts().plot(kind="pie",autopct = "%1.1f",legend = True,ylabel="Percentage")
# Out:
# <Axes: ylabel='Percentage'>

# %%
categorical_columns.columns
# Out:
# Index(['make', 'fuel_type', 'aspiration', 'body_style', 'drive_wheels',
#        'engine_location', 'engine_type', 'fuel_system'],
#       dtype='object')

# %%
df["drive_wheels"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='drive_wheels'>

# %%
sns.countplot(data=df,x="drive_wheels")
# Out:
# <Axes: xlabel='drive_wheels', ylabel='count'>

# %%
df["drive_wheels"].value_counts().plot(kind="pie",autopct = "%1.1f",legend = True,ylabel="Percentage")
# Out:
# <Axes: ylabel='Percentage'>

# %%
categorical_columns.columns
# Out:
# Index(['make', 'fuel_type', 'aspiration', 'body_style', 'drive_wheels',
#        'engine_location', 'engine_type', 'fuel_system'],
#       dtype='object')

# %%
categorical_columns.columns
# Out:
# Index(['make', 'fuel_type', 'aspiration', 'body_style', 'drive_wheels',
#        'engine_location', 'engine_type', 'fuel_system'],
#       dtype='object')

# %%
df["engine_location"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='engine_location'>

# %%
sns.countplot(data=df,x="engine_location")
# Out:
# <Axes: xlabel='engine_location', ylabel='count'>

# %%
df["engine_location"].value_counts().plot(kind="pie",autopct = "%1.1f",legend = True,ylabel="Percentage")
# Out:
# <Axes: ylabel='Percentage'>

# %%
categorical_columns.columns
# Out:
# Index(['make', 'fuel_type', 'aspiration', 'body_style', 'drive_wheels',
#        'engine_location', 'engine_type', 'fuel_system'],
#       dtype='object')

# %%
df["engine_type"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='engine_type'>

# %%
sns.countplot(data=df,x="engine_type")
# Out:
# <Axes: xlabel='engine_type', ylabel='count'>

# %%
df["engine_type"].value_counts().plot(kind="pie",autopct = "%1.1f",legend = True,ylabel="Percentage")
# Out:
# <Axes: ylabel='Percentage'>

# %%
categorical_columns.columns
# Out:
# Index(['make', 'fuel_type', 'aspiration', 'body_style', 'drive_wheels',
#        'engine_location', 'engine_type', 'fuel_system'],
#       dtype='object')

# %%
df["fuel_system"].value_counts().plot(kind="bar")
# Out:
# <Axes: xlabel='fuel_system'>

# %%
sns.countplot(data=df,x="fuel_system")
# Out:
# <Axes: xlabel='fuel_system', ylabel='count'>

# %%
df["fuel_system"].value_counts().plot(kind="pie",autopct = "%1.1f",legend = True,ylabel="Percentage")
# Out:
# <Axes: ylabel='Percentage'>

# %% [markdown]
# # Bivariate Analysis
#
# Bivariate Analysis is a kind of statistical analysis in whinch two variables are observed against each other

# %%
obj = df.select_dtypes(include="object")

# %%
sns.countplot(data = df,x="body_style",hue="fuel_type")
# Out:
# <Axes: xlabel='body_style', ylabel='count'>

# %% [markdown]
# **Insights from above Count Plot**
# 1. The gas(fuel) consumption rate for **convertible** cars is 6 count/frequency
# 2. The gas(fuel) consumption rate for **hatchback** cars is 69 count/frequency and The diesel(fuel) consumption rate for **hatchback** cars is 1 count/frequency
# 3. The gas(fuel) consumption rate for **sedan** cars is 81 count/frequency and The diesel(fuel) consumption rate for **sedan** cars is 15 count/frequency
# 4. The gas(fuel) consumption rate for **wagon** cars is 22 count/frequency and The diesel(fuel) consumption rate for **wagon** cars is 3 count/frequency
# 5. The gas(fuel) consumption rate for **hardtop** cars is 7 count/frequency and The diesel(fuel) consumption rate for **hardtop** cars is 1 count/frequency

# %%
obj.columns
# Out:
# Index(['make', 'fuel_type', 'aspiration', 'body_style', 'drive_wheels',
#        'engine_location', 'engine_type', 'fuel_system'],
#       dtype='object')

# %%
pd.crosstab(df["body_style"],df["fuel_type"])
# Out:
# fuel_type    diesel  gas
# body_style
# convertible       0    6
# hardtop           1    7
# hatchback         1   69
# sedan            15   81
# wagon             3   22

# %% [markdown]
# **Insights from above Cross Tab**
# 1. The gas(fuel) consumption rate for **convertible** cars is 6 count/frequency
# 2. The gas(fuel) consumption rate for **hatchback** cars is 69 count/frequency and The diesel(fuel) consumption rate for **hatchback** cars is 1 count/frequency
# 3. The gas(fuel) consumption rate for **sedan** cars is 81 count/frequency and The diesel(fuel) consumption rate for **sedan** cars is 15 count/frequency
# 4. The gas(fuel) consumption rate for **wagon** cars is 22 count/frequency and The diesel(fuel) consumption rate for **wagon** cars is 3 count/frequency
# 5. The gas(fuel) consumption rate for **hardtop** cars is 7 count/frequency and The diesel(fuel) consumption rate for **hardtop** cars is 1 count/frequency

# %% [markdown]
# ### Categorical Vs Numerical
#  1. Bar Chart
#  2. GroupBy
#  3. Pivot Table
#  4. Line Chart

# %%
df.head()
# Out:
#           make fuel_type aspiration  num_of_doors   body_style drive_wheels  \
# 0  alfa-romero       gas        std           2.0  convertible          rwd
# 1  alfa-romero       gas        std           2.0  convertible          rwd
# 2  alfa-romero       gas        std           2.0    hatchback          rwd
# 3         audi       gas        std           4.0        sedan          fwd
# 4         audi       gas        std           4.0        sedan          4wd
#
#   engine_location  wheel_base  length  width  height  curb_weight engine_type  \
# 0           front        88.6   168.8   64.1    48.8         2548        dohc
# 1           front        88.6   168.8   64.1    48.8         2548        dohc
# 2           front        94.5   171.2   65.5    52.4         2823        ohcv
# 3           front        99.8   176.6   66.2    54.3         2337         ohc
# 4           front        99.4   176.6   66.4    54.3         2824         ohc
#
# ...

# %%
df.groupby("engine_location")["price"].mean()
# Out:
# engine_location
# front    12742.188119
# rear     34528.000000
# Name: price, dtype: float64

# %% [markdown]
# ### Numerical Vs Numerical
#  1. Correlation
#  2. Scatter Plot

# %%
sns.scatterplot(data=df,x="wheel_base",y="length")
# Out:
# <Axes: xlabel='wheel_base', ylabel='length'>

# %% [markdown]
# ### Multivariate Analysis

# %%
sns.heatmap(df.corr(numeric_only=True),annot=True)
# Out:
# <Axes: >
